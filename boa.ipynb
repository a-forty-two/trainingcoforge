# %%
# DBUTILS
accesskey = 'oHTUfbbvJuoxUiLzChQNVSzrzrUAzEB1NGqpBBerssjXrulfFiX5htVkKFhppW7pB49EZd5n6saZmuy4ocd2Rw=='
bloburl = 'wasbs://data@thisisrandomstorage.blob.core.windows.net'
dbutils.fs.mount(
    source=bloburl,
    mount_point = '/mnt/lake',
    extra_configs= {
        'fs.azure.account.key.thisisrandomstorage.blob.core.windows.net':accesskey
    }
)

# azure.account.key
# azure.account.sas 
# openID
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: True</div>

# %%
mydata = spark.read.csv('/mnt/lake/breastcancer_data.csv', header=True)
mydata.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+---------+-----------+------------+--------------+---------+---------------+----------------+--------------+-------------+----------------------+
#       id|diagnosis|radius_mean|texture_mean|perimeter_mean|area_mean|smoothness_mean|compactness_mean|concavity_mean|symmetry_mean|fractal_dimension_mean|
# +--------+---------+-----------+------------+--------------+---------+---------------+----------------+--------------+-------------+----------------------+
#   842302|        M|      17.99|       10.38|         122.8|     1001|         0.1184|          0.2776|        0.3001|       0.2419|               0.07871|
#   842517|        M|      20.57|       17.77|         132.9|     1326|        0.08474|         0.07864|        0.0869|       0.1812|               0.05667|
# 84300903|        M|      19.69|       21.25|           130|     1203|         0.1096|          0.1599|        0.1974|       0.2069|               0.05999|
# 84348301|        M|      11.42|       20.38|         77.58|    386.1|         0.1425|          0.2839|        0.2414|       0.2597|               0.09744|
# 84358402|        M|      20.29|       14.34|         135.1|     1297|         0.1003|          0.1328|         0.198|       0.1809|               0.05883|
# +--------+---------+-----------+------------+--------------+---------+---------------+----------------+--------------+-------------+----------------------+
# only showing top 5 rows
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
